# %% [markdown]
# # Quantization
#
# <br>
#
# **Run in [Google Colab](https://colab.research.google.com/) for GPU access.**<br>
# (You can try running it on your computer first. If it's too slow, switch to Google Colab for GPU acceleration.)
#
# <br>
#
# ---
#
# <br>
#
# Quantization is one of the most common techniques used to make large models fit on smaller hardware and run faster. In this notebook we'll build an intuition for what it is, how it works under the hood, and see it applied to a real model.

# %% [markdown]
# <br>
#
# ## 1. Why Quantization?
#
# Every parameter (weight) in a neural network is a number, and that number has to be stored in memory using some numeric format.
# <br>
#
# ![](../_images/computer-memory.jpg)
#
# <br>
# The most common training format is **FP32** (32-bit floating point) — 4 bytes per number.
#
# The problem: modern models have billions of parameters, so storing everything in FP32 quickly requires enormous amounts of memory.
#
# Instead of storing weights in FP32, we can represent them using other numerical formats that require fewer bits. Common alternatives include FP16 and BF16 (16-bit floating point), as well as INT8 and INT4 (8-bit and 4-bit integers).
# <br>
#
# ![](../_images/quantization-formats.png)
#
# <br>
# Using lower-precision formats **reduces the model's memory footprint and can speed up inference**, at the cost of a small loss in numerical precision.
#
# Quantization is the process of converting a model from a higher-precision format (such as FP32) to one of these lower-precision representations.
#
#
# <br>
#
# Let's do the math for a 7-billion-parameter model at different precisions.

# %%
def model_memory_gb(num_params_billion, bits_per_param):
    bytes_per_param = bits_per_param / 8
    total_bytes = num_params_billion * 1e9 * bytes_per_param
    return total_bytes / (1024 ** 3)  # convert to GB

num_params = 7  # billion, e.g. a 7B model like Mistral-7B or SQLCoder-7B

precisions = {
    "FP32 (32-bit)": 32,
    "FP16 / BF16 (16-bit)": 16,
    "INT8 (8-bit)": 8,
    "INT4 (4-bit)": 4,
}

print(f"Memory required to load a {num_params}B-parameter model:\n")
for name, bits in precisions.items():
    gb = model_memory_gb(num_params, bits)
    print(f"  {name:<22} ~ {gb:.1f} GB")
# Out:
# Memory required to load a 7B-parameter model:
#
#   FP32 (32-bit)          ~ 26.1 GB
#   FP16 / BF16 (16-bit)   ~ 13.0 GB
#   INT8 (8-bit)           ~ 6.5 GB
#   INT4 (4-bit)           ~ 3.3 GB

# %% [markdown]
# A 7B model needs **~28 GB** at FP32 — more than most consumer and even many cloud GPUs have available. At 4-bit, the same model needs **~3.5 GB**.
#
# This is the core motivation for quantization: **shrink the numeric representation of the weights so the model fits in available memory and runs faster**, ideally with minimal loss in output quality.
#
# > **Important distinction:** Quantization is applied to a model's weights. It does not change what the model has learned — it changes how precisely those learned values are *stored and computed*.

# %% [markdown]
# <br>
#
# ## 2. What Is Quantization, Conceptually?
#
# Floating-point numbers (like FP32) can represent a huge range of values with high precision. Quantization **maps** those high-precision values onto a much smaller set of discrete values — typically low-bit integers.
#
# **Analogy:**
# - Imagine measuring temperature. A precise thermometer might read `21.847°C`.
# - If you round to the nearest whole degree, you get `22°C`.
# - You've lost some precision, but you can still tell hot from cold, and you save a lot of space if you only ever need to store whole numbers.
#
# Quantization does the same thing to model weights: it rounds a wide range of float values into a small number of integer "buckets," while trying to preserve the overall shape/relationships of the original data.

# %% [markdown]
# <br>
#
# ## 3. Precision Types Walkthrough
#
# | Format | Bits | Typical Use |
# |---|---|---|
# | FP32 | 32 | Default training precision |
# | FP16 / BF16 | 16 | Common for training/inference speedups, minimal quality loss |
# | INT8 | 8 | Common for inference, noticeable memory savings |
# | INT4 (e.g. NF4) | 4 | Aggressive compression, used to fit very large models on limited hardware |
#
# <br>
#
# ![](../_images/quantization-example.webp)
#
# <br>
#
# As we go from FP32 → INT4:
# - **Memory footprint shrinks** (roughly linearly with bit-width)
# - **Inference can get faster** (less data to move around, sometimes faster integer math)
# - **Precision decreases**, which *can* translate into lower-quality outputs — the risk grows as bit-width drops
#
# There's no universally "correct" precision — it's a tradeoff decision based on your hardware constraints and how sensitive your task is to small numerical errors.

# %% [markdown]
# <br>
#
# ## 4. Post-Training Quantization vs. Quantization-Aware Training
#
# There are two main ways quantization gets applied:
#
# - **Post-Training Quantization (PTQ)**: Take an already-trained model and quantize its weights *after* training is complete, typically right before inference.
# - **Quantization-Aware Training (QAT)**: Simulate the effects of quantization *during* training, so the model's weights adapt to the precision loss as it learns. This usually produces better results at very low bit-widths, but requires retraining the model — more time and compute.
#
# **In practice:** most people quantizing an existing open-source model (e.g., loading a model from Hugging Face to run on a single GPU) are doing PTQ. That's the pattern you'll see used with tools like `bitsandbytes`.

# %% [markdown]
# <br>
#
# ## 5. Hands-On: Quantizing a Real Model
#
# Now let's apply this to an actual model. We'll load a small open-source model twice:
# 1. Once at full precision
# 2. Once with 4-bit quantization via `BitsAndBytesConfig`
#
# ...and compare memory usage.
#
# > This section requires a GPU runtime (Colab: **Runtime → Change runtime type → GPU**).

# %%
# !pip install -q -U transformers accelerate bitsandbytes
# Out:
# WARNING: Ignoring invalid distribution -ransformers (/Users/luis/.pyenv/versions/3.10.13/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/luis/.pyenv/versions/3.10.13/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/luis/.pyenv/versions/3.10.13/lib/python3.10/site-packages)
#     WARNING: Ignoring invalid distribution -ransformers (/Users/luis/.pyenv/versions/3.10.13/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/luis/.pyenv/versions/3.10.13/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/luis/.pyenv/versions/3.10.13/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/luis/.pyenv/versions/3.10.13/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/luis/.pyenv/versions/3.10.13/lib/python3.10/site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch

# For this demo, we will load "GPT-2", a transformer-based language model developed by OpenAI, known for its text generation capabilities.
# 
# It's a relatively small model, good for demonstrating the mechanics quickly

model_name = "gpt2"

# %% [markdown]
# <br>
#
# ### 5.1 Load at full precision and check memory footprint

# %%
model_fp32 = AutoModelForCausalLM.from_pretrained(model_name)

fp32_params = sum(p.numel() for p in model_fp32.parameters())
fp32_bytes = sum(p.numel() * p.element_size() for p in model_fp32.parameters())

print(f"Parameters: {fp32_params:,}")
print(f"Memory footprint (full precision): {fp32_bytes / (1024**2):.1f} MB")

# del model_fp32
# torch.cuda.empty_cache()
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Parameters: 124,439,808
# Memory footprint (full precision): 474.7 MB

# %% [markdown]
# <br>
#
# ### 5.2 Load with 4-bit quantization and compare

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
)

model_4bit = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map="auto",
)

# bitsandbytes reports memory footprint directly
print(f"Memory footprint (4-bit): {model_4bit.get_memory_footprint() / (1024**2):.1f} MB")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# [W725 17:05:08.841603000 unwind.cpp:12] Warning: record_context_cpp is not support on non-linux non-x86_64 platforms (function operator())
# C0725 17:05:09.399000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/0] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:09.399000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/0]   'mps',
# C0725 17:05:09.399000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/0]   torch.float32,
# C0725 17:05:09.399000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/0]   def inner_fn(index, rindex):
# C0725 17:05:09.399000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/0]       i0 = index
# C0725 17:05:09.399000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/0]       r0_0 = rindex
# C0725 17:05:09.399000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/0]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:09.399000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/0]       tmp1 = ops.abs(tmp0)
# C0725 17:05:09.399000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/0]       return tmp1
# C0725 17:05:09.399000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/0]   ,
# C0725 17:05:09.399000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/0]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:09.399000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/0]   reduction_ranges=[s7],
# C0725 17:05:09.399000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/0]   reduction_type=max,
# C0725 17:05:09.399000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/0]   origin_node=getitem,
# C0725 17:05:09.399000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/0]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:09.399000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/0] ))
# C0725 17:05:10.171000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/0] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s39 - (Mod(s39, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:10.171000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/0]   'mps',
# C0725 17:05:10.171000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/0]   torch.float32,
# C0725 17:05:10.171000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/0]   def inner_fn(index, rindex):
# C0725 17:05:10.171000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/0]       i0 = index
# C0725 17:05:10.171000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/0]       r0_0 = rindex
# C0725 17:05:10.171000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/0]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:10.171000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/0]       tmp1 = ops.abs(tmp0)
# C0725 17:05:10.171000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/0]       return tmp1
# C0725 17:05:10.171000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/0]   ,
# C0725 17:05:10.171000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/0]   ranges=[((s39 - (Mod(s39, s7)))//s7)],
# C0725 17:05:10.171000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/0]   reduction_ranges=[s7],
# C0725 17:05:10.171000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/0]   reduction_type=max,
# C0725 17:05:10.171000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/0]   origin_node=getitem,
# C0725 17:05:10.171000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/0]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:10.171000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/0] ))
# C0725 17:05:11.122000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/1] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:11.122000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/1]   'mps',
# C0725 17:05:11.122000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/1]   torch.float32,
# C0725 17:05:11.122000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/1]   def inner_fn(index, rindex):
# C0725 17:05:11.122000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/1]       i0 = index
# C0725 17:05:11.122000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/1]       r0_0 = rindex
# C0725 17:05:11.122000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/1]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:11.122000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/1]       tmp1 = ops.abs(tmp0)
# C0725 17:05:11.122000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/1]       return tmp1
# C0725 17:05:11.122000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/1]   ,
# C0725 17:05:11.122000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/1]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:11.122000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/1]   reduction_ranges=[s7],
# C0725 17:05:11.122000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/1]   reduction_type=max,
# C0725 17:05:11.122000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/1]   origin_node=getitem,
# C0725 17:05:11.122000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/1]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:11.122000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/1] ))
# C0725 17:05:11.791000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/1] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:11.791000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/1]   'mps',
# C0725 17:05:11.791000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/1]   torch.float32,
# C0725 17:05:11.791000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/1]   def inner_fn(index, rindex):
# C0725 17:05:11.791000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/1]       i0 = index
# C0725 17:05:11.791000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/1]       r0_0 = rindex
# C0725 17:05:11.791000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/1]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:11.791000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/1]       tmp1 = ops.abs(tmp0)
# C0725 17:05:11.791000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/1]       return tmp1
# C0725 17:05:11.791000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/1]   ,
# C0725 17:05:11.791000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/1]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:11.791000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/1]   reduction_ranges=[s7],
# C0725 17:05:11.791000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/1]   reduction_type=max,
# C0725 17:05:11.791000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/1]   origin_node=getitem,
# C0725 17:05:11.791000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/1]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:11.791000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/1] ))
# C0725 17:05:12.338000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/2] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:12.338000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/2]   'mps',
# C0725 17:05:12.338000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/2]   torch.float32,
# C0725 17:05:12.338000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/2]   def inner_fn(index, rindex):
# C0725 17:05:12.338000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/2]       i0 = index
# C0725 17:05:12.338000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/2]       r0_0 = rindex
# C0725 17:05:12.338000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/2]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:12.338000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/2]       tmp1 = ops.abs(tmp0)
# C0725 17:05:12.338000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/2]       return tmp1
# C0725 17:05:12.338000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/2]   ,
# C0725 17:05:12.338000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/2]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:12.338000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/2]   reduction_ranges=[s7],
# C0725 17:05:12.338000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/2]   reduction_type=max,
# C0725 17:05:12.338000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/2]   origin_node=getitem,
# C0725 17:05:12.338000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/2]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:12.338000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/2] ))
# C0725 17:05:12.897000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/2] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:12.897000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/2]   'mps',
# C0725 17:05:12.897000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/2]   torch.float32,
# C0725 17:05:12.897000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/2]   def inner_fn(index, rindex):
# C0725 17:05:12.897000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/2]       i0 = index
# C0725 17:05:12.897000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/2]       r0_0 = rindex
# C0725 17:05:12.897000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/2]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:12.897000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/2]       tmp1 = ops.abs(tmp0)
# C0725 17:05:12.897000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/2]       return tmp1
# C0725 17:05:12.897000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/2]   ,
# C0725 17:05:12.897000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/2]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:12.897000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/2]   reduction_ranges=[s7],
# C0725 17:05:12.897000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/2]   reduction_type=max,
# C0725 17:05:12.897000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/2]   origin_node=getitem,
# C0725 17:05:12.897000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/2]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:12.897000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/2] ))
# C0725 17:05:13.362000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/3] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:13.362000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/3]   'mps',
# C0725 17:05:13.362000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/3]   torch.float32,
# C0725 17:05:13.362000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/3]   def inner_fn(index, rindex):
# C0725 17:05:13.362000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/3]       i0 = index
# C0725 17:05:13.362000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/3]       r0_0 = rindex
# C0725 17:05:13.362000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/3]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:13.362000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/3]       tmp1 = ops.abs(tmp0)
# C0725 17:05:13.362000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/3]       return tmp1
# C0725 17:05:13.362000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/3]   ,
# C0725 17:05:13.362000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/3]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:13.362000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/3]   reduction_ranges=[s7],
# C0725 17:05:13.362000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/3]   reduction_type=max,
# C0725 17:05:13.362000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/3]   origin_node=getitem,
# C0725 17:05:13.362000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/3]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:13.362000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/3] ))
# C0725 17:05:13.833000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/3] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:13.833000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/3]   'mps',
# C0725 17:05:13.833000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/3]   torch.float32,
# C0725 17:05:13.833000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/3]   def inner_fn(index, rindex):
# C0725 17:05:13.833000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/3]       i0 = index
# C0725 17:05:13.833000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/3]       r0_0 = rindex
# C0725 17:05:13.833000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/3]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:13.833000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/3]       tmp1 = ops.abs(tmp0)
# C0725 17:05:13.833000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/3]       return tmp1
# C0725 17:05:13.833000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/3]   ,
# C0725 17:05:13.833000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/3]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:13.833000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/3]   reduction_ranges=[s7],
# C0725 17:05:13.833000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/3]   reduction_type=max,
# C0725 17:05:13.833000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/3]   origin_node=getitem,
# C0725 17:05:13.833000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/3]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:13.833000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/3] ))
# C0725 17:05:14.293000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/4] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:14.293000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/4]   'mps',
# C0725 17:05:14.293000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/4]   torch.float32,
# C0725 17:05:14.293000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/4]   def inner_fn(index, rindex):
# C0725 17:05:14.293000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/4]       i0 = index
# C0725 17:05:14.293000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/4]       r0_0 = rindex
# C0725 17:05:14.293000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/4]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:14.293000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/4]       tmp1 = ops.abs(tmp0)
# C0725 17:05:14.293000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/4]       return tmp1
# C0725 17:05:14.293000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/4]   ,
# C0725 17:05:14.293000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/4]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:14.293000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/4]   reduction_ranges=[s7],
# C0725 17:05:14.293000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/4]   reduction_type=max,
# C0725 17:05:14.293000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/4]   origin_node=getitem,
# C0725 17:05:14.293000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/4]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:14.293000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/4] ))
# C0725 17:05:14.786000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/4] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:14.786000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/4]   'mps',
# C0725 17:05:14.786000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/4]   torch.float32,
# C0725 17:05:14.786000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/4]   def inner_fn(index, rindex):
# C0725 17:05:14.786000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/4]       i0 = index
# C0725 17:05:14.786000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/4]       r0_0 = rindex
# C0725 17:05:14.786000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/4]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:14.786000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/4]       tmp1 = ops.abs(tmp0)
# C0725 17:05:14.786000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/4]       return tmp1
# C0725 17:05:14.786000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/4]   ,
# C0725 17:05:14.786000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/4]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:14.786000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/4]   reduction_ranges=[s7],
# C0725 17:05:14.786000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/4]   reduction_type=max,
# C0725 17:05:14.786000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/4]   origin_node=getitem,
# C0725 17:05:14.786000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/4]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:14.786000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/4] ))
# C0725 17:05:15.221000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/5] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:15.221000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/5]   'mps',
# C0725 17:05:15.221000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/5]   torch.float32,
# C0725 17:05:15.221000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/5]   def inner_fn(index, rindex):
# C0725 17:05:15.221000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/5]       i0 = index
# C0725 17:05:15.221000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/5]       r0_0 = rindex
# C0725 17:05:15.221000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/5]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:15.221000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/5]       tmp1 = ops.abs(tmp0)
# C0725 17:05:15.221000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/5]       return tmp1
# C0725 17:05:15.221000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/5]   ,
# C0725 17:05:15.221000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/5]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:15.221000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/5]   reduction_ranges=[s7],
# C0725 17:05:15.221000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/5]   reduction_type=max,
# C0725 17:05:15.221000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/5]   origin_node=getitem,
# C0725 17:05:15.221000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/5]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:15.221000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/5] ))
# C0725 17:05:15.832000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/5] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:15.832000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/5]   'mps',
# C0725 17:05:15.832000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/5]   torch.float32,
# C0725 17:05:15.832000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/5]   def inner_fn(index, rindex):
# C0725 17:05:15.832000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/5]       i0 = index
# C0725 17:05:15.832000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/5]       r0_0 = rindex
# C0725 17:05:15.832000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/5]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:15.832000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/5]       tmp1 = ops.abs(tmp0)
# C0725 17:05:15.832000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/5]       return tmp1
# C0725 17:05:15.832000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/5]   ,
# C0725 17:05:15.832000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/5]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:15.832000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/5]   reduction_ranges=[s7],
# C0725 17:05:15.832000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/5]   reduction_type=max,
# C0725 17:05:15.832000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/5]   origin_node=getitem,
# C0725 17:05:15.832000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/5]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:15.832000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/5] ))
# C0725 17:05:16.264000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/6] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:16.264000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/6]   'mps',
# C0725 17:05:16.264000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/6]   torch.float32,
# C0725 17:05:16.264000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/6]   def inner_fn(index, rindex):
# C0725 17:05:16.264000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/6]       i0 = index
# C0725 17:05:16.264000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/6]       r0_0 = rindex
# C0725 17:05:16.264000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/6]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:16.264000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/6]       tmp1 = ops.abs(tmp0)
# C0725 17:05:16.264000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/6]       return tmp1
# C0725 17:05:16.264000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/6]   ,
# C0725 17:05:16.264000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/6]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:16.264000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/6]   reduction_ranges=[s7],
# C0725 17:05:16.264000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/6]   reduction_type=max,
# C0725 17:05:16.264000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/6]   origin_node=getitem,
# C0725 17:05:16.264000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/6]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:16.264000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/6] ))
# C0725 17:05:16.730000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/6] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:16.730000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/6]   'mps',
# C0725 17:05:16.730000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/6]   torch.float32,
# C0725 17:05:16.730000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/6]   def inner_fn(index, rindex):
# C0725 17:05:16.730000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/6]       i0 = index
# C0725 17:05:16.730000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/6]       r0_0 = rindex
# C0725 17:05:16.730000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/6]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:16.730000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/6]       tmp1 = ops.abs(tmp0)
# C0725 17:05:16.730000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/6]       return tmp1
# C0725 17:05:16.730000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/6]   ,
# C0725 17:05:16.730000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/6]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:16.730000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/6]   reduction_ranges=[s7],
# C0725 17:05:16.730000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/6]   reduction_type=max,
# C0725 17:05:16.730000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/6]   origin_node=getitem,
# C0725 17:05:16.730000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/6]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:16.730000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/6] ))
# C0725 17:05:17.184000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/7] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:17.184000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/7]   'mps',
# C0725 17:05:17.184000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/7]   torch.float32,
# C0725 17:05:17.184000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/7]   def inner_fn(index, rindex):
# C0725 17:05:17.184000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/7]       i0 = index
# C0725 17:05:17.184000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/7]       r0_0 = rindex
# C0725 17:05:17.184000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/7]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:17.184000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/7]       tmp1 = ops.abs(tmp0)
# C0725 17:05:17.184000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/7]       return tmp1
# C0725 17:05:17.184000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/7]   ,
# C0725 17:05:17.184000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/7]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:17.184000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/7]   reduction_ranges=[s7],
# C0725 17:05:17.184000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/7]   reduction_type=max,
# C0725 17:05:17.184000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/7]   origin_node=getitem,
# C0725 17:05:17.184000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/7]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:17.184000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/7] ))
# C0725 17:05:17.657000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/7] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:17.657000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/7]   'mps',
# C0725 17:05:17.657000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/7]   torch.float32,
# C0725 17:05:17.657000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/7]   def inner_fn(index, rindex):
# C0725 17:05:17.657000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/7]       i0 = index
# C0725 17:05:17.657000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/7]       r0_0 = rindex
# C0725 17:05:17.657000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/7]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:17.657000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/7]       tmp1 = ops.abs(tmp0)
# C0725 17:05:17.657000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/7]       return tmp1
# C0725 17:05:17.657000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/7]   ,
# C0725 17:05:17.657000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/7]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:17.657000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/7]   reduction_ranges=[s7],
# C0725 17:05:17.657000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/7]   reduction_type=max,
# C0725 17:05:17.657000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/7]   origin_node=getitem,
# C0725 17:05:17.657000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/7]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:17.657000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/7] ))
# C0725 17:05:18.084000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/8] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:18.084000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/8]   'mps',
# C0725 17:05:18.084000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/8]   torch.float32,
# C0725 17:05:18.084000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/8]   def inner_fn(index, rindex):
# C0725 17:05:18.084000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/8]       i0 = index
# C0725 17:05:18.084000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/8]       r0_0 = rindex
# C0725 17:05:18.084000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/8]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:18.084000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/8]       tmp1 = ops.abs(tmp0)
# C0725 17:05:18.084000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/8]       return tmp1
# C0725 17:05:18.084000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/8]   ,
# C0725 17:05:18.084000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/8]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:18.084000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/8]   reduction_ranges=[s7],
# C0725 17:05:18.084000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/8]   reduction_type=max,
# C0725 17:05:18.084000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/8]   origin_node=getitem,
# C0725 17:05:18.084000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/8]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:18.084000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/8] ))
# C0725 17:05:18.547000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/8] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:18.547000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/8]   'mps',
# C0725 17:05:18.547000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/8]   torch.float32,
# C0725 17:05:18.547000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/8]   def inner_fn(index, rindex):
# C0725 17:05:18.547000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/8]       i0 = index
# C0725 17:05:18.547000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/8]       r0_0 = rindex
# C0725 17:05:18.547000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/8]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:18.547000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/8]       tmp1 = ops.abs(tmp0)
# C0725 17:05:18.547000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/8]       return tmp1
# C0725 17:05:18.547000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/8]   ,
# C0725 17:05:18.547000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/8]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:18.547000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/8]   reduction_ranges=[s7],
# C0725 17:05:18.547000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/8]   reduction_type=max,
# C0725 17:05:18.547000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/8]   origin_node=getitem,
# C0725 17:05:18.547000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/8]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:18.547000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/8] ))
# C0725 17:05:19.146000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/9] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:19.146000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/9]   'mps',
# C0725 17:05:19.146000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/9]   torch.float32,
# C0725 17:05:19.146000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/9]   def inner_fn(index, rindex):
# C0725 17:05:19.146000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/9]       i0 = index
# C0725 17:05:19.146000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/9]       r0_0 = rindex
# C0725 17:05:19.146000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/9]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:19.146000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/9]       tmp1 = ops.abs(tmp0)
# C0725 17:05:19.146000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/9]       return tmp1
# C0725 17:05:19.146000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/9]   ,
# C0725 17:05:19.146000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/9]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:19.146000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/9]   reduction_ranges=[s7],
# C0725 17:05:19.146000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/9]   reduction_type=max,
# C0725 17:05:19.146000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/9]   origin_node=getitem,
# C0725 17:05:19.146000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/9]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:19.146000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/9] ))
# C0725 17:05:19.610000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/9] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:19.610000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/9]   'mps',
# C0725 17:05:19.610000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/9]   torch.float32,
# C0725 17:05:19.610000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/9]   def inner_fn(index, rindex):
# C0725 17:05:19.610000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/9]       i0 = index
# C0725 17:05:19.610000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/9]       r0_0 = rindex
# C0725 17:05:19.610000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/9]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:19.610000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/9]       tmp1 = ops.abs(tmp0)
# C0725 17:05:19.610000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/9]       return tmp1
# C0725 17:05:19.610000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/9]   ,
# C0725 17:05:19.610000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/9]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:19.610000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/9]   reduction_ranges=[s7],
# C0725 17:05:19.610000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/9]   reduction_type=max,
# C0725 17:05:19.610000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/9]   origin_node=getitem,
# C0725 17:05:19.610000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/9]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:19.610000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/9] ))
# C0725 17:05:20.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/10] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:20.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/10]   'mps',
# C0725 17:05:20.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/10]   torch.float32,
# C0725 17:05:20.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/10]   def inner_fn(index, rindex):
# C0725 17:05:20.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/10]       i0 = index
# C0725 17:05:20.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/10]       r0_0 = rindex
# C0725 17:05:20.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/10]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:20.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/10]       tmp1 = ops.abs(tmp0)
# C0725 17:05:20.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/10]       return tmp1
# C0725 17:05:20.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/10]   ,
# C0725 17:05:20.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/10]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:20.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/10]   reduction_ranges=[s7],
# C0725 17:05:20.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/10]   reduction_type=max,
# C0725 17:05:20.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/10]   origin_node=getitem,
# C0725 17:05:20.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/10]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:20.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/10] ))
# C0725 17:05:20.537000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/10] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:20.537000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/10]   'mps',
# C0725 17:05:20.537000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/10]   torch.float32,
# C0725 17:05:20.537000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/10]   def inner_fn(index, rindex):
# C0725 17:05:20.537000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/10]       i0 = index
# C0725 17:05:20.537000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/10]       r0_0 = rindex
# C0725 17:05:20.537000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/10]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:20.537000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/10]       tmp1 = ops.abs(tmp0)
# C0725 17:05:20.537000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/10]       return tmp1
# C0725 17:05:20.537000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/10]   ,
# C0725 17:05:20.537000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/10]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:20.537000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/10]   reduction_ranges=[s7],
# C0725 17:05:20.537000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/10]   reduction_type=max,
# C0725 17:05:20.537000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/10]   origin_node=getitem,
# C0725 17:05:20.537000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/10]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:20.537000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/10] ))
# C0725 17:05:20.978000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/11] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:20.978000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/11]   'mps',
# C0725 17:05:20.978000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/11]   torch.float32,
# C0725 17:05:20.978000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/11]   def inner_fn(index, rindex):
# C0725 17:05:20.978000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/11]       i0 = index
# C0725 17:05:20.978000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/11]       r0_0 = rindex
# C0725 17:05:20.978000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/11]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:20.978000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/11]       tmp1 = ops.abs(tmp0)
# C0725 17:05:20.978000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/11]       return tmp1
# C0725 17:05:20.978000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/11]   ,
# C0725 17:05:20.978000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/11]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:20.978000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/11]   reduction_ranges=[s7],
# C0725 17:05:20.978000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/11]   reduction_type=max,
# C0725 17:05:20.978000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/11]   origin_node=getitem,
# C0725 17:05:20.978000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/11]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:20.978000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/11] ))
# C0725 17:05:21.450000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/11] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:21.450000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/11]   'mps',
# C0725 17:05:21.450000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/11]   torch.float32,
# C0725 17:05:21.450000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/11]   def inner_fn(index, rindex):
# C0725 17:05:21.450000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/11]       i0 = index
# C0725 17:05:21.450000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/11]       r0_0 = rindex
# C0725 17:05:21.450000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/11]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:21.450000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/11]       tmp1 = ops.abs(tmp0)
# C0725 17:05:21.450000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/11]       return tmp1
# C0725 17:05:21.450000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/11]   ,
# C0725 17:05:21.450000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/11]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:21.450000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/11]   reduction_ranges=[s7],
# C0725 17:05:21.450000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/11]   reduction_type=max,
# C0725 17:05:21.450000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/11]   origin_node=getitem,
# C0725 17:05:21.450000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/11]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:21.450000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/11] ))
# C0725 17:05:21.906000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/12] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:21.906000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/12]   'mps',
# C0725 17:05:21.906000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/12]   torch.float32,
# C0725 17:05:21.906000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/12]   def inner_fn(index, rindex):
# C0725 17:05:21.906000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/12]       i0 = index
# C0725 17:05:21.906000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/12]       r0_0 = rindex
# C0725 17:05:21.906000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/12]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:21.906000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/12]       tmp1 = ops.abs(tmp0)
# C0725 17:05:21.906000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/12]       return tmp1
# C0725 17:05:21.906000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/12]   ,
# C0725 17:05:21.906000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/12]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:21.906000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/12]   reduction_ranges=[s7],
# C0725 17:05:21.906000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/12]   reduction_type=max,
# C0725 17:05:21.906000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/12]   origin_node=getitem,
# C0725 17:05:21.906000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/12]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:21.906000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/12] ))
# C0725 17:05:22.370000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/12] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:22.370000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/12]   'mps',
# C0725 17:05:22.370000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/12]   torch.float32,
# C0725 17:05:22.370000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/12]   def inner_fn(index, rindex):
# C0725 17:05:22.370000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/12]       i0 = index
# C0725 17:05:22.370000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/12]       r0_0 = rindex
# C0725 17:05:22.370000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/12]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:22.370000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/12]       tmp1 = ops.abs(tmp0)
# C0725 17:05:22.370000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/12]       return tmp1
# C0725 17:05:22.370000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/12]   ,
# C0725 17:05:22.370000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/12]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:22.370000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/12]   reduction_ranges=[s7],
# C0725 17:05:22.370000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/12]   reduction_type=max,
# C0725 17:05:22.370000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/12]   origin_node=getitem,
# C0725 17:05:22.370000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/12]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:22.370000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/12] ))
# ...
# C0725 17:05:52.611000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/43]       r0_0 = rindex
# C0725 17:05:52.611000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/43]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:52.611000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/43]       tmp1 = ops.abs(tmp0)
# C0725 17:05:52.611000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/43]       return tmp1
# C0725 17:05:52.611000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/43]   ,
# C0725 17:05:52.611000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/43]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:52.611000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/43]   reduction_ranges=[s7],
# C0725 17:05:52.611000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/43]   reduction_type=max,
# C0725 17:05:52.611000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/43]   origin_node=getitem,
# C0725 17:05:52.611000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/43]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:52.611000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/43] ))
# C0725 17:05:53.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/44] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:53.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/44]   'mps',
# C0725 17:05:53.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/44]   torch.float32,
# C0725 17:05:53.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/44]   def inner_fn(index, rindex):
# C0725 17:05:53.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/44]       i0 = index
# C0725 17:05:53.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/44]       r0_0 = rindex
# C0725 17:05:53.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/44]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:53.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/44]       tmp1 = ops.abs(tmp0)
# C0725 17:05:53.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/44]       return tmp1
# C0725 17:05:53.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/44]   ,
# C0725 17:05:53.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/44]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:53.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/44]   reduction_ranges=[s7],
# C0725 17:05:53.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/44]   reduction_type=max,
# C0725 17:05:53.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/44]   origin_node=getitem,
# C0725 17:05:53.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/44]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:53.041000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/44] ))
# C0725 17:05:53.510000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/44] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:53.510000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/44]   'mps',
# C0725 17:05:53.510000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/44]   torch.float32,
# C0725 17:05:53.510000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/44]   def inner_fn(index, rindex):
# C0725 17:05:53.510000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/44]       i0 = index
# C0725 17:05:53.510000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/44]       r0_0 = rindex
# C0725 17:05:53.510000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/44]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:53.510000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/44]       tmp1 = ops.abs(tmp0)
# C0725 17:05:53.510000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/44]       return tmp1
# C0725 17:05:53.510000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/44]   ,
# C0725 17:05:53.510000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/44]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:53.510000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/44]   reduction_ranges=[s7],
# C0725 17:05:53.510000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/44]   reduction_type=max,
# C0725 17:05:53.510000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/44]   origin_node=getitem,
# C0725 17:05:53.510000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/44]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:53.510000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/44] ))
# C0725 17:05:53.936000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/45] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:53.936000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/45]   'mps',
# C0725 17:05:53.936000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/45]   torch.float32,
# C0725 17:05:53.936000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/45]   def inner_fn(index, rindex):
# C0725 17:05:53.936000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/45]       i0 = index
# C0725 17:05:53.936000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/45]       r0_0 = rindex
# C0725 17:05:53.936000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/45]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:53.936000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/45]       tmp1 = ops.abs(tmp0)
# C0725 17:05:53.936000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/45]       return tmp1
# C0725 17:05:53.936000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/45]   ,
# C0725 17:05:53.936000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/45]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:53.936000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/45]   reduction_ranges=[s7],
# C0725 17:05:53.936000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/45]   reduction_type=max,
# C0725 17:05:53.936000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/45]   origin_node=getitem,
# C0725 17:05:53.936000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/45]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:53.936000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/45] ))
# C0725 17:05:54.727000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/45] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:54.727000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/45]   'mps',
# C0725 17:05:54.727000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/45]   torch.float32,
# C0725 17:05:54.727000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/45]   def inner_fn(index, rindex):
# C0725 17:05:54.727000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/45]       i0 = index
# C0725 17:05:54.727000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/45]       r0_0 = rindex
# C0725 17:05:54.727000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/45]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:54.727000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/45]       tmp1 = ops.abs(tmp0)
# C0725 17:05:54.727000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/45]       return tmp1
# C0725 17:05:54.727000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/45]   ,
# C0725 17:05:54.727000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/45]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:54.727000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/45]   reduction_ranges=[s7],
# C0725 17:05:54.727000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/45]   reduction_type=max,
# C0725 17:05:54.727000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/45]   origin_node=getitem,
# C0725 17:05:54.727000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/45]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:54.727000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/45] ))
# C0725 17:05:55.189000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/46] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:55.189000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/46]   'mps',
# C0725 17:05:55.189000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/46]   torch.float32,
# C0725 17:05:55.189000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/46]   def inner_fn(index, rindex):
# C0725 17:05:55.189000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/46]       i0 = index
# C0725 17:05:55.189000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/46]       r0_0 = rindex
# C0725 17:05:55.189000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/46]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:55.189000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/46]       tmp1 = ops.abs(tmp0)
# C0725 17:05:55.189000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/46]       return tmp1
# C0725 17:05:55.189000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/46]   ,
# C0725 17:05:55.189000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/46]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:55.189000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/46]   reduction_ranges=[s7],
# C0725 17:05:55.189000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/46]   reduction_type=max,
# C0725 17:05:55.189000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/46]   origin_node=getitem,
# C0725 17:05:55.189000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/46]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:55.189000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/46] ))
# C0725 17:05:55.660000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/46] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:55.660000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/46]   'mps',
# C0725 17:05:55.660000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/46]   torch.float32,
# C0725 17:05:55.660000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/46]   def inner_fn(index, rindex):
# C0725 17:05:55.660000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/46]       i0 = index
# C0725 17:05:55.660000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/46]       r0_0 = rindex
# C0725 17:05:55.660000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/46]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:55.660000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/46]       tmp1 = ops.abs(tmp0)
# C0725 17:05:55.660000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/46]       return tmp1
# C0725 17:05:55.660000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/46]   ,
# C0725 17:05:55.660000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/46]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:55.660000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/46]   reduction_ranges=[s7],
# C0725 17:05:55.660000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/46]   reduction_type=max,
# C0725 17:05:55.660000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/46]   origin_node=getitem,
# C0725 17:05:55.660000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/46]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:55.660000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/46] ))
# C0725 17:05:56.092000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/47] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:56.092000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/47]   'mps',
# C0725 17:05:56.092000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/47]   torch.float32,
# C0725 17:05:56.092000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/47]   def inner_fn(index, rindex):
# C0725 17:05:56.092000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/47]       i0 = index
# C0725 17:05:56.092000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/47]       r0_0 = rindex
# C0725 17:05:56.092000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/47]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:56.092000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/47]       tmp1 = ops.abs(tmp0)
# C0725 17:05:56.092000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/47]       return tmp1
# C0725 17:05:56.092000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/47]   ,
# C0725 17:05:56.092000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/47]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:56.092000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/47]   reduction_ranges=[s7],
# C0725 17:05:56.092000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/47]   reduction_type=max,
# C0725 17:05:56.092000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/47]   origin_node=getitem,
# C0725 17:05:56.092000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/47]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:56.092000 95416 site-packages/torch/_inductor/scheduler.py:1198] [0/47] ))
# C0725 17:05:56.561000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/47] Error in codegen for ComputedBuffer(name='buf0', layout=FixedLayout('mps:0', torch.float32, size=[((s28 - (Mod(s28, s7)))//s7)], stride=[1]), data=Reduction(
# C0725 17:05:56.561000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/47]   'mps',
# C0725 17:05:56.561000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/47]   torch.float32,
# C0725 17:05:56.561000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/47]   def inner_fn(index, rindex):
# C0725 17:05:56.561000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/47]       i0 = index
# C0725 17:05:56.561000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/47]       r0_0 = rindex
# C0725 17:05:56.561000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/47]       tmp0 = ops.load(arg1_1, r0_0 + s7 * i0)
# C0725 17:05:56.561000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/47]       tmp1 = ops.abs(tmp0)
# C0725 17:05:56.561000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/47]       return tmp1
# C0725 17:05:56.561000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/47]   ,
# C0725 17:05:56.561000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/47]   ranges=[((s28 - (Mod(s28, s7)))//s7)],
# C0725 17:05:56.561000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/47]   reduction_ranges=[s7],
# C0725 17:05:56.561000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/47]   reduction_type=max,
# C0725 17:05:56.561000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/47]   origin_node=getitem,
# C0725 17:05:56.561000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/47]   origins=OrderedSet([max_1, abs_1])
# C0725 17:05:56.561000 95416 site-packages/torch/_inductor/scheduler.py:1198] [1/47] ))
# Memory footprint (4-bit): 191.2 MB

# %% [markdown]
# <br>
#
# ### 5.3 Compare output quality

# %%
#
# Full precission model
#

tokenizer = AutoTokenizer.from_pretrained(model_name)

prompt = "In deep learning, Quantization is a technique that"
inputs = tokenizer(prompt, return_tensors="pt").to(model_fp32.device)

output = model_fp32.generate(**inputs, max_new_tokens=30)
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# In deep learning, Quantization is a technique that allows you to build a neural network that can be used to predict the future.
#
# The goal of this post is to show you how to build

# %%
# 
# 4-bit quantization
# 

tokenizer = AutoTokenizer.from_pretrained(model_name)

prompt = "In deep learning, Quantization is a technique that"
inputs = tokenizer(prompt, return_tensors="pt").to(model_4bit.device)

output = model_4bit.generate(**inputs, max_new_tokens=30)
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# In deep learning, Quantization is a technique that allows you to build a neural network that can be used to predict the future.
#
# Quantization is a technique that allows you to build a neural

# %% [markdown]
# <br>
#
# ## 6. Tradeoffs and Limitations
#
# **When quantization helps most:**
# - Running large models on limited GPU/CPU memory
# - Deploying to edge devices or cost-sensitive inference environments
# - Serving many concurrent requests where memory is the bottleneck
#
# **When to be cautious:**
# - Very low bit-widths (e.g., 2-bit) can noticeably degrade output quality, especially for smaller models that have less redundancy to spare
# - Quantized models may need slightly different prompting or may behave inconsistently compared to full-precision versions
# - Quantization is a runtime/deployment concern — it doesn't fix a model that was poorly trained or fine-tuned for the task in the first place

# %% [markdown]
# <br>
#
# ## 7. Key Takeaways
#
# - Quantization reduces the number of bits used to store model weights, shrinking memory footprint and often speeding up inference
# - It works by mapping a wide range of float values onto a smaller set of discrete values, using a scale (and sometimes a zero-point)
# - **Post-Training Quantization (PTQ)** is applied to an already-trained model at load time — no retraining needed. This is the approach used with tools like `bitsandbytes`
# - **Quantization-Aware Training (QAT)** bakes precision-awareness into training itself, and generally performs better at very low bit-widths, but costs more to produce
# - Lower bit-widths mean bigger memory savings but a higher risk of quality degradation — it's a tradeoff to tune based on your hardware and task
